# %% [markdown]
# <a href="https://colab.research.google.com/github/gowrilvinod/Generative-AI-Using-HuggingFace/blob/main/HuggingFace_And_Langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 2.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...

# %%
from google.colab import userdata
sec_key = userdata.get("HF_TOKEN")
print(sec_key)
# Out:
# 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

# %% [markdown]
# **HuggingFaceEndpoint**

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key=userdata.get("HUGGINGFACEHUB")
print(sec_key)
# Out:
# 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

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = sec_key

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
llm = HuggingFaceEndpoint(repo_id = repo_id ,temperature =0.7 , max_lenth = 128, token = sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_lenth is not default parameter.
#                     max_lenth was transferred to model_kwargs.
#                     Please make sure that max_lenth is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.2', temperature=0.7, model_kwargs={'max_lenth': 128, 'token': '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'}, model='mistralai/Mistral-7B-Instruct-v0.2', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.2', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.2', timeout=120)>)

# %%
llm.invoke("What is a neural network in deep learning")
# Out:
# '?\n\nA neural network in deep learning is a computational model inspired by the structure and function of the human brain. It consists of interconnected processing nodes, called artificial neurons, organized in layers. Each neuron receives inputs from the previous layer, applies a non-linear activation function to the weighted sum of inputs, and passes the output to the next layer. The layers can be further categorized into input, hidden, and output layers. Deep learning neural networks have multiple hidden layers, enabling them to learn complex representations of data, making them particularly effective for handling large and intricate datasets. These networks can be trained using backpropagation, a supervised learning algorithm, to adjust the weights and biases to minimize the error between the predicted and actual outputs.'

# %%
from langchain import PromptTemplate , LLMChain

question = " Who won Miss World 2017"
template = """ Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])

chain = LLMChain(llm=llm, prompt=prompt)
chain.run(question)
# Out:
# '\n\n1. Miss World is an annual international beauty pageant.\n2. It was first held in 1951 and is now one of the most famous pageants in the world.\n3. The winner is chosen based on several criteria including beauty, intelligence, and personality.\n4. The Miss World 2017 pageant took place on November 18, 2017, in Sanya, China.\n5. The winner was announced as Manushi Chhillar from India.\n\nSo, Manushi Chhillar won Miss World 2017.'

# %% [markdown]
# **Hugging FacePipeline**

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import pipeline, AutoTokenizer , AutoModelForCausalLM

# %%
model_id = "openai-community/gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7d03477a5c90>)

# %%
hf.invoke("What is a neural network in deep learning")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "What is a neural network in deep learning?\n\nIn this episode I'll answer some common questions in these areas and provide some examples so, feel free to use them in your training! https://github.com/wishimens/layers.\n\nThe general purpose of this piece is not to give advice, though this is an essential way to gain a broader understanding of how deep learning works and what the tools are for. The goal of this discussion is to give you, hopefully, an understanding on the techniques that make"

# %%
import torch
from langchain_huggingface.llms import HuggingFacePipeline

# Check CUDA availability
if torch.cuda.is_available():
    device = 0  # Use the first GPU
else:
    device = -1  # Fallback to CPU

gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device=device,  # Use determined device
    # You can also try using device_map="auto" for automatic allocation
)

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
chain=prompt|gpu_llm

# %%
question="What is artificial intelligence?"
chain.invoke({"question":question})
# Out:
# "Question: What is artificial intelligence?\n\nAnswer: Let's think step by step.\n\nA simple rule for intelligent AI is that as quickly as you learn, you can learn to avoid it. When we are faced with a difficult task like"
